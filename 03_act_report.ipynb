# %%
#@title
import os

import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

os.chdir('/content/drive/MyDrive/Colab Files/Udacity/Udacity - Data Analyst/projects/02_WeRateDogs') # change directory
# !ls # check directory

# %% [markdown]
# # Introduction
#
# Having done with the data wrangling process described in document two (i.e 02_wrangle_act), we discuss some key insights from the data and provide one additional visualization.
#
# As a reminder, the dataset under focus is the WeRateDogs®
# [@dog_rates](https://twitter.com/dog_rates) data. WeRateDogs® is a professional dog ratings source according to their Twitter page bio.

# %% [markdown]
# ![Data Process](https://drive.google.com/uc?id=1fJRMtwndXXq1yRv9NZIajpHR6chwNHOw)
#
# <!-- ![datawrangling-udacity.drawio.png](data:image/png;base64,...) -->
#
# At this point, we are at the last stage of our data analysis process. We have gathered, assessed, cleaned, combined and stored our data into a master csv data.

# %% [markdown]
# # Data Insights

# %% [markdown]
# ## Top Ten Retweets
#
# One of our interest is what are the tweets that drives engagement on the platform. A good metric for this is the retweet count. So we asked ourselves, what did WeRateDogs®
# [@dog_rates](https://twitter.com/dog_rates) write on their Twitter page that earned them so much engagement for that post (in terms of retweets i.e. rts).

# %%
#@title
pd.read_csv('data/top_ten_rt.csv')
# Out:
#                                                                                                                                          text  \
# 0                         Here's a doggo realizing you can stand in a pool. 13/10 enlightened af (vid by Tina Conrad) https://t.co/7wE9LTEXC4
# 1                                                       This is Stephan. He just wants to help. 13/10 such a good boy https://t.co/DkBYaCAg2d
# 2  Here's a doggo blowing bubbles. It's downright legendary. 13/10 would watch on repeat forever (vid by Kent Duryee) https://t.co/YcXgHfp1EC
# 3                             Here's a super supportive puppo participating in the Toronto  #WomensMarch today. 13/10 https://t.co/nTz3FtorBc
# 4                                  This is Duddles. He did an attempt. 13/10 someone help him (vid by Georgia Felici) https://t.co/UDT7ZkcTgY
# ...

# %% [markdown]
# From the above dataframe, we see the tweets that earned WeRateDogs®
# [@dog_rates](https://twitter.com/dog_rates) such high engagement. Easy to spot out here is the unique ratings which WeRateDogs®
# [@dog_rates](https://twitter.com/dog_rates) gave the dogs i.e 13/10, 14/10 e.t.c.

# %% [markdown]
# ## Top Ten Likes/Favourites

# %% [markdown]
# Another way to check for heightened engagement on Twitter is via likes/facourites. So we asked ourselves again, what did WeRateDogs®
# [@dog_rates](https://twitter.com/dog_rates) write on their Twitter page that earned them so much engagement for that post (in terms of likes).

# %%
#@title
pd.read_csv('data/top_ten_likes.csv')
# Out:
#                                                                                                                                                                   text  \
# 0                                                      Here's a super supportive puppo participating in the Toronto  #WomensMarch today. 13/10 https://t.co/nTz3FtorBc
# 1                                                  Here's a doggo realizing you can stand in a pool. 13/10 enlightened af (vid by Tina Conrad) https://t.co/7wE9LTEXC4
# 2                                                           This is Duddles. He did an attempt. 13/10 someone help him (vid by Georgia Felici) https://t.co/UDT7ZkcTgY
# 3                                                                                This is Stephan. He just wants to help. 13/10 such a good boy https://t.co/DkBYaCAg2d
# ...

# %% [markdown]
# Just like earlier, looking at the above dataframe, we noticed a similar exceptionally high rating in the tweets that led to very high engagements using the like/favourite metric. We may conclude that this unique form of rating is what made WeRateDogs®
# [@dog_rates](https://twitter.com/dog_rates) popular.

# %% [markdown]
# ## The most popular dog breed prediction.
#
# One of the dataset used in our analysis is a tweet image prediciton data which was built using a neural network. We were interested in investigating what dog breed was most popular using the `p1` prediction after harmonising that `p1`, `p2` and `p3` returned that the image is that of a dog (i.e True).

# %%
#@title
pd.read_csv('data/p1_pred_dog_breeds.csv')
# Out:
#                          dog_breed  count
# 0                 golden_retriever    117
# 1                         Pembroke     77
# 2               Labrador_retriever     74
# 3                        Chihuahua     50
# 4                              pug     39
# 5                       Pomeranian     28
# 6                             chow     26
# 7                       toy_poodle     26
# 8                         malamute     26
# 9                          Samoyed     25
# 10                  cocker_spaniel     23
# 11                  French_bulldog     20
# 12              miniature_pinscher     20
# 13                  Siberian_husky     17
# 14                 German_shepherd     17
# 15                          beagle     17
# 16       Staffordshire_bullterrier     16
# 17                     Maltese_dog     15
# 18               Shetland_sheepdog     15
# 19                        Shih-Tzu     15
# 20        Chesapeake_Bay_retriever     15
# ...

# %% [markdown]
# The above shows us the top thirty (30) dog breed predictions while the golden retriever breed is the most popular.

# %% [markdown]
# ## Day of the week with most tweets
#
# Another variable of interest if finding out the day of the week with the most engagement. The dataframe below helps us to answer that question.

# %%
#@title
pd.read_csv('data/tweetdays.csv', header = 0, names = ['day_of_week', 'count'])
# Out:
#   day_of_week  count
# 0      Monday    352
# 1     Tuesday    312
# 2   Wednesday    310
# 3    Thursday    295
# 4      Friday    292
# 5      Sunday    268
# 6    Saturday    268

# %% [markdown]
# From the above, WeRateDogs®
# [@dog_rates](https://twitter.com/dog_rates) tweets more on Mondays and least on Sundays.

# %% [markdown]
# ## Day of the week with most engagement
#
# Now, after combining for likes and retweets, we checked with day of the week has the most engagements.

# %% [markdown]
# ![Engagements](data:image/png;base64,...)

# %% [markdown]
# From the above image we see that Sunday has the least aggregate engagements whereas Wednesdays have the most.

# %% [markdown]
# # Conclusion
#
# In this report, we have been able to explain four insights derived from the datasets which we wrangled and provided an additional visualization
